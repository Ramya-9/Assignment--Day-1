# %%
x = int(input("first number "))
y = int(input("second number "))
#subtraction
diff = x - y
print("my Subtraction is", diff)
# Multipication
Prod = x * y
print("my Multiplication is ",Prod)
#Division
Div = x / y
print("my Division is ",Div)
# Out:
# first number 25
# second number 5
# my Subtraction is 20
# my Multiplication is  125
# my Division is  5.0
